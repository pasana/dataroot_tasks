# %%
import json

with open('X_5.json') as data_file:
    X = json.load(data_file)
print len(X)
# Out:
# 125

# %%
for i in range(0, len(X)):
    print i+1, X[i]['name']
    print
# Out:
# 1 Онкологический центр Сети больниц Acıbadem
#
# 2 Онкологический центр Медицинского центра Рамбам
#
# 3 Онкологический центр Клиники Университета имени Людвига Максимилиана в Мюнхене
#
# 4 Отделение рака Больницы Токуда
#
# 5 Отделение рака Мемориального онкологического центра им. Слоуна-Кеттеринга
#
# 6 Онкологический центр Больницы Liv Hospital
#
# 7 Онкологический центр Медицинского Центра Анадолу (Anadolu)
#
# 8 Отделение рака Медицинского центра им. Сураски (Ихилов)
#
# 9 Онкологический центр Клиники Хелиос
#
# 10 Отделение рака Клиники Дортмунда
#
# 11 Онкологический центр Больницы Гиль Медицинского Университета Гачон
#
# 12 Онкологический центр Сети клиник Манипал ( Manipal Hospitals )
#
# 13 Онкологический центр Международного медицинского центра «Вивантес» (Берлин)
#
# 14 Отделение рака Золингена академической больницы университета Кёльн
#
# 15 Онкологический центр Сети больниц Memorial
#
# 16 Онкологический центр Cети частных клиник Асклепиос
#
# ...
